# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('data1TP1.txt', sep='\t')  # read the data file
plt.scatter(df['A'], df['Y'])
plt.xlabel('A')
plt.ylabel('Y')
plt.show()

df = pd.read_csv('data1TP1.txt', sep='\t')  # read the data file
plt.scatter(df['B'], df['Y'])
plt.xlabel('B')
plt.ylabel('Y')
plt.show()

df = pd.read_csv('data1TP1.txt', sep='\t')  # read the data file
plt.scatter(df['C'], df['Y'])
plt.xlabel('C')
plt.ylabel('Y')
plt.show()

df = pd.read_csv('data1TP1.txt', sep='\t')  # read the data file
plt.scatter(df['D'], df['Y'])
plt.xlabel('D')
plt.ylabel('Y')
plt.show()

df = pd.read_csv('data1TP1.txt', sep='\t')  # read the data file
plt.scatter(df['E'], df['Y'])
plt.xlabel('E')
plt.ylabel('Y')
plt.show()
